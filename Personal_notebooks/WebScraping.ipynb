# %% [markdown]
# # 1.Librería Request

# %%
url = "https://www.officialcharts.com/charts/singles-chart/20240112/7501/"

# %%
import requests

# %%
html = requests.get(url)

# %% [markdown]
# > - Cuando lo ejecutamos sin nigún tipo de atributo, ni argumento ni nada obtenemos un `<Response [200]>`
# > - Es un código de tres cifras que nos indica el estado de la petición que estamos haciendo. Si el codigo empieza por 1,2,3 estamos recibiendo un mensaje de "ok". Si empieza por 4 o 5 quiere decir que hay un error
#
# > - HTTP Response **1XX** = el servidor donde nos conectamos continua procesando ya que debe haber algún paso intermedio para completar la request, pero todo va correctamente (no es nada común)
# > - HTTP Response **2XX** = indica que la petición ha sido procesada correctamente y la orden se ha ejecutado. Es el mesaje que esperamos y que indica que todo esta ok
# > - HTTP Response **3XX** = se trata de mensajes de redirección de la URL de la petición, pero esto también indica que el proceso marcha correctamente
# > - HTTP Response **4XX** = la petición no se ha completado porque hay un error del lado del cliente (nosotros). Habitualmente errores en la construcción de la petición o en nuestro user agent. Error 404, indica que estamos intentando acceder a una parte del servidor que no existe.
# > - HTTP Response **5XX** = indica que hay un problema del lado del servidor y que esta request no se puede completar por el momento. Error que no queremos ver ni en pintura.

# %%
html
# Out:
# <Response [200]>

# %% [markdown]
# > - Del atributo `.content` nosotros sacaremos la información que necesitamos

# %%
html.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head><meta charset="utf-8">\n<title>Official Singles Chart Top 100 on 12&#x2F;1&#x2F;2024 | Official Charts</title>\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="msapplication-TileColor" content="#f5f2e7">\n<meta name="msapplication-config" content="/favicons/browserconfig.xml">\n<meta name="theme-color" content="#f5f2e7">\n<link rel="apple-touch-icon" sizes="180x180" href="/favicons/apple-touch-icon.png">\n<link rel="icon" type="image/png" sizes="32x32" href="/favicons/favicon-32x32.png">\n<link rel="icon" type="image/png" sizes="16x16" href="/favicons/favicon-16x16.png">\n<link rel="manifest" href="/favicons/site.webmanifest">\n<link rel="mask-icon" color="#0029f3" href="favicons/safari-pinned-tab.svg">\n<link rel="shortcut icon" href="/favicons/favicon.ico">\n<script src="/js/quantcast.js" async="async"></script>\n<script src="https://cdn.tagdeliver.com/cipt/17187.js" async="async"></script>\n<meta name="title" content="Official Singles Chart Top 100 on 12/1/2024 | Official Charts">\n<meta name="keywords" content=", , ,">\n<meta property="og:site_name" content="Official Charts">\n<meta property="og:type" content="Chart">\n<meta property="og:url" content="https://www.officialcharts.com/charts/singles-chart/20240112/7501/">\n<meta property="og:title" content="Official Singles Chart Top 100 on 12/1/2024">\n<meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:site" content="@officialcharts">\n<meta name="twitter:title" content="Official Singles Chart Top 100 on 12/1/2024">\n<meta name="twitter:url" content="https://www.officialcharts.com/charts/singles-chart/20240112/7501/">\n<link rel="canonical" href="https://www.officialcharts.com/charts/singles-chart/20240112/7501/"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/entry.e8041814.js"><link rel="preload" as="style" href="/_nuxt/entry.9fdc2d3c.css"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/_...slug_.2c14fe7b.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalTabs.a8ab167e.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/Messages.c452b58f.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/Message.b8597474.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalNodeChart.b25277de.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalBlock.8abd91d6.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalBlockChartList.1a16e96d.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalBlockPrimisAdvert.f33e3228.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/minus.d9fa42af.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/TrackInfo.4915e3c9.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/play-solid.1451c5ef.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/TrackInfoIndividual.fff55fab.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalBlockContentListing.18505f55.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalNodeTeaser.50d98a53.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalCommentAnonymous.7faf602f.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalComment.f17cf7cd.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalCommentForm.4566b393.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalBlockCountdownBlock.2e0c83dd.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalBlockContentIgniteAdvert.50f53cf7.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalBlockArchiveAccessBlock.4a03e2e2.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/ChartPicker.8852d496.js"><link rel="modulepreload" as="script" crossorigin href="/_nuxt/DrupalBlockNewsletterBlock.a9868247.js"><l ...

# %% [markdown]
# # 2.robots.txt

# %% [markdown]
# > - Define a qué partes podemos acceder dentro de una página web
# > - Es como unas puertas que pone la página web para indicar a que aspectos de la página web no se le permite entrar a un usuario
# > - Normalmente son partes administrativas de una página web
# > - Para acceder a estas puertas basta con escribir  `/robots.txt` en la URL principal de la página web
# > - Estas limitaciones no son vinculantes, es decir, si te las saltas, la ley te ampara, no estas cometiendo ningún delito

# %% [markdown]
# # 3.BeautifulSoup, DOM y Tags

# %% [markdown]
# > - **DOM = Document Object Model**. Es una interfaz para programar documentos web. Se basa en un sistema de tags (etiquetas) las cuales habitualmente se anidan (nestean) como en un diccionario. Estos tags hacen referencia a partes de las páginas web. Son como diccionarios pero que en vez de tener llaves tienen tags.

# %%
# !pip install bs4
from bs4 import BeautifulSoup
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %% [markdown]
# > - Esta libreria nos ayuda a gestionar estos tags
# > - Ahora construiremos un objeto soup que nos ayudará a encontrar estos tags dentro del html

# %%
soup = BeautifulSoup(html.content)

# %% [markdown]
# > - Lo que hace es parsear todos los tags, es decir, estructurar la información de nuestro html

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head><meta charset="utf-8"/>
# <title>Official Singles Chart Top 100 on 12/1/2024 | Official Charts</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="#f5f2e7" name="msapplication-TileColor"/>
# <meta content="/favicons/browserconfig.xml" name="msapplication-config"/>
# <meta content="#f5f2e7" name="theme-color"/>
# <link href="/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/favicons/site.webmanifest" rel="manifest"/>
# <link color="#0029f3" href="favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/favicons/favicon.ico" rel="shortcut icon"/>
# <script async="async" src="/js/quantcast.js"></script>
# <script async="async" src="https://cdn.tagdeliver.com/cipt/17187.js"></script>
# <meta content="Official Singles Chart Top 100 on 12/1/2024 | Official Charts" name="title"/>
# <meta content=", , ," name="keywords"/>
# <meta content="Official Charts" property="og:site_name"/>
# <meta content="Chart" property="og:type"/>
# <meta content="https://www.officialcharts.com/charts/singles-chart/20240112/7501/" property="og:url"/>
# <meta content="Official Singles Chart Top 100 on 12/1/2024" property="og:title"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@officialcharts" name="twitter:site"/>
# <meta content="Official Singles Chart Top 100 on 12/1/2024" name="twitter:title"/>
# <meta content="https://www.officialcharts.com/charts/singles-chart/20240112/7501/" name="twitter:url"/>
# <link href="https://www.officialcharts.com/charts/singles-chart/20240112/7501/" rel="canonical"/><link as="script" crossorigin="" href="/_nuxt/entry.e8041814.js" rel="modulepreload"/><link as="style" href="/_nuxt/entry.9fdc2d3c.css" rel="preload"/><link as="script" crossorigin="" href="/_nuxt/_...slug_.2c14fe7b.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalTabs.a8ab167e.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/Messages.c452b58f.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/Message.b8597474.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalNodeChart.b25277de.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalBlock.8abd91d6.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalBlockChartList.1a16e96d.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalBlockPrimisAdvert.f33e3228.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/minus.d9fa42af.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/TrackInfo.4915e3c9.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/play-solid.1451c5ef.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/TrackInfoIndividual.fff55fab.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalBlockContentListing.18505f55.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalNodeTeaser.50d98a53.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalCommentAnonymous.7faf602f.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalComment.f17cf7cd.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalCommentForm.4566b393.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalBlockCountdownBlock.2e0c83dd.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalBlockContentIgniteAdvert.50f53cf7.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalBlockArchiveAccessBlock.4a03e2e2.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/ChartPicker.8852d496.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalBlockNewsletterBlock.a9868247.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalBlockFollowUsBlock.68b6a4a8.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/logo-arrows-cobalt.099dd8c9.js" rel="modulepreload"/><link as="script" crossorigin="" href="/_nuxt/DrupalBlockBasic.e659b4da.js" rel="modulepreload"/><link as="image" href="/_nuxt/logo-arrows-white.e19034b3.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/tiktok.dddc9625.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/instagram.02ecfca6.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/twitter.0ef54c74.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/radio1.3b875721.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/facebook.df385ad4.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/youtube.ba6286a5.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/envelope.40a1fd20.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/logo-cobalt.728eee02.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/list-solid.9536925a.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/rectangle-history-regular.7d95a7f8.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/info.698782dd.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/circle-xmark-regular.4be073a6.svg" rel="prefetch" type="image/svg+xml"/><link as="image" href="/_nuxt/spinner-third-pink.5e3cdee2.svg" rel="prefetch" type="image/svg+xml"/><link ...
# <body class="bg-design-greige text-black oc-2023 anonymous"><div id="__nuxt"><!--[--><div class="py-5 bg-brand-pink flex justify-center items-center min-h-[50px] md:min-h-[90px] lg:min-h-[290px]"><div id="ci_ad_970x250_1"></div></div><header class="px-4 pt-4 lg:pb-4 w-full bg-design-greige border-b-4 border-b-brand-pink shadow-sm text-brand-pink" id="header"><div class="lg:container l-0 r-0 flex justify-between items-center"><a class="hidden lg:block" href="/"><img alt="The Official Charts Company logo" class="md:w-[200px]" height="68" src="/_nuxt/logo-cobalt.728eee02.svg" width="200"/><span class="sr-only">The Official Charts Company</span></a><div class="flex main-nav lg:ml-8"><div class="block lg:hidden" id="mobileMenu"><button aria-label="Main navigation" class="rotate-180 bg-brand-cobalt rounded-full"><span class="top -translate-y-[6px]"></span><span class="mid"></span><span class="bot translate-y-[6px]"></span></button><div class="bg-design-greige text-brand-cobalt overflow-y-auto text-center text-lg z-10 absolute top-[calc(var(--header-height)-var(--padd))] left-0 block w-screen h-screen uppercase" style="display:none;"><nav><div><ol><!--[--><li><a class="" href="/news/">News</a></li><li><a class="" href="/new-releases/">New releases</a></li><li><a class="" href="/charts/">Charts</a></li><li><a class="" href="/artists/">Artists</a></li><li><a class="" href="/songs-albums/">Songs &amp; Albums</a></li><li><a class="" href="/about/">About</a></li><!--]--></ol></div></nav><ol class="flex space-x-4 items-center justify-center mt-8 opacity-80"><!--[--><li><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><a data-v-5784ed69-s="" href="https://www.tiktok.com/@officialukcharts" target="_blank"><img alt="TikTok icon" class="" data-v-5784ed69-s="" height="27" src="/_nuxt/tiktok.dddc9625.svg" width="25"/><span class="sr-only" data-v-5784ed69-s="">TikTok</span></a><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Follow us on TikTok<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></li><li><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><a data-v-5784ed69-s="" href="https://www.instagram.com/officialcharts/" target="_blank"><img alt="Instagram icon" class="" data-v-5784ed69-s="" height="27" src="/_nuxt/instagram.02ecfca6.svg" width="28"/><span class="sr-only" data-v-5784ed69-s="">Instagram</span></a><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Follow us on Instagram<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></li><li><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><a data-v-5784ed69-s="" href="https://twitter.com/OfficialCharts" target="_blank"><img alt="Twitter icon" class="" data-v-5784ed69-s="" height="27" src="/_nuxt/twitter.0ef54c74.svg" width="34"/><span class="sr-only" data-v-5784ed69-s="">Twitter</span></a><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Follow us on Twitter<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></li><li><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><a data-v-5784ed69-s="" href="https://www.bbc.co.uk/programmes/b006wkgn" target="_blank"><img alt="Radio 1 icon" class="" data-v-5784ed69-s="" height="27" src="/_nuxt/radio1.3b875721.svg" width="28"/><span class="sr-only" data-v-5784ed69-s="">Radio1</span></a><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Check out the Radio 1 Chart show<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></di ...
# <p> </p>
# </div></div></section><!--[--><!--[--><!--[--><!--[--><div class="contents"><section class="chart-list hidden" element="drupal-block-chart-list" style=""><div class="list-mode relative"><h3 class="sticky top-0 bg-design-greige m-0 pt-1"><div class="md:rounded-t-lg chart-title flex items-center md:justify-center text-white px-2 pr-13 text-lg bg-brand-cobalt min-h-[50px] pt-2 pb-1"><div class="text-lg sm:text-xl relative pl-9 label mx-auto"><img alt="Official Charts logo" height="30px" src="/logos/logo-arrows-white.svg" width="27px"/> <span>Official</span> <span class="font-light">Singles Chart</span></div><!-- --></div></h3><button class="chart-switcher left-7 z-10 lg:hidden" style=""><span style="display:none;"><img alt="View as list icon" class="inline-block" height="11" src="/_nuxt/list-solid.9536925a.svg" width="17"/> view as list</span><span style=""><img alt="View as cards icon" class="inline-block" height="18" src="/_nuxt/rectangle-history-regular.7d95a7f8.svg" width="18"/> view as cards</span></button><div class="chart-content" style=""><!-- --><div class="no-intro chart-items"><!--[--><!--[--><div class="primis chart-item relative text-right" data-info="info-429496-0" data-item="item-429496-0" data-player="player-429496-0" style="background-color: #acb4b6;"><div class="chart-item-content relative flex w-full"><div class="position"><span class="digits1 chart-key font-bold"><span class="sr-only">Number </span><strong>1</strong></span><div class="chart-image"><img alt="STICK SEASON cover art" class="chart-image-small rounded-md shadow-sm" height="80" loading="lazy" src="https://is5-ssl.mzstatic.com/image/thumb/Music112/v4/5a/3f/8e/5a3f8ec5-be0d-580c-6f2e-8634121d5e68/22UM1IM01116.rgb.jpg/80x80bb.jpg" width="80"/><img alt="STICK SEASON cover art" class="chart-image-large rounded-lg shadow-md absolute md:static w-[210px] 2xs:w-[220px] xs:w-[240px] top-[80px] 3xs:top-[90px] 2xs:top-[85px] xs:top-[105px] md:top-[95px] right-0 sm:right-auto" height="247" loading="lazy" src="https://is5-ssl.mzstatic.com/image/thumb/Music112/v4/5a/3f/8e/5a3f8ec5-be0d-580c-6f2e-8634121d5e68/22UM1IM01116.rgb.jpg/247x247bb.jpg" width="247"/><button aria-label="Play audio preview" class="audio-play audio-control" data-progress-half="lt50" title="Play"><audio data-artist="NOAH KAHAN" data-title="STICK SEASON" preload="none" src="https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview122/v4/1e/63/48/1e6348d4-e72a-df7a-2f8e-64b9533836af/mzaf_12112022263606846296.plus.aac.p.m4a" type="audio/mpeg"></audio><div class="action"></div><div class="progress-wrapper"><div class="progress"><div class="left-side half-circle"></div><div class="right-side half-circle"></div></div><div class="shadow"></div></div></button></div></div><div class="description block"><p><a class="chart-name font-bold inline-block" href="/songs/noah-kahan-stick-season/"><!-- --><span class="movement-icon"></span><span>STICK SEASON</span></a><br/><a class="chart-artist text-lg inline-block" href="/artist/63540/noah-kahan/"><span>NOAH KAHAN</span></a></p><div class="stats"><ol class="text-2xs sm:text-sm"><li class="movement px-2 py-1 rounded-md inline-block mr-1 sm:mr-2"><!--[--><span title="Last week">LW: <span class="text-brand-pink font-bold">1</span></span><!--]--><span class="hidden sm:inline-block">, </span></li><li class="peak px-2 py-1 rounded-md inline-block mr-1 sm:mr-2">Peak: <span class="text-brand-cobalt font-bold">1</span><span>, </span></li><li class="weeks px-2 py-1 rounded-md inline-block mr-1 sm:mr-2">Weeks: <span class="text-brand-pink font-bold">15</span><!-- --></li><!-- --></ol><button aria-label="Read more data about this item" class="more-info self-start relative"><img alt="Read more icon" class="action open" height="40" src="/_nuxt/info.698782dd.svg" width="40"/><img alt="Close read more icon" class="action close" height="40" src="/_nuxt/circle-xmark-regular.4be073a6.svg" width="40"/><img alt="Loading spinner" class="absolute top-0 left-0 animate-spin" height ...
# </div><div class="teaser-banner teaser-banner-alt">Film Chart</div></div><div class="text text-sm xs:text-base leading-[26px] xl:text-xl font-semibold text-white">The Marvels storms straight to Number 1 on Official Film Chart</div><!--]--></a><a class="col teaser sm:col-1/2" href="/chart-news/frank-farian-dies-boney-m/"><!--[--><div class="image relative overflow-hidden"><div> <img alt="Frank Farian" class="rounded-t-lg sm:rounded-lg object-cover aspect-teaser w-full" height="253" loading="lazy" sizes="100vw" src="/sites/default/files/styles/teaser_card_small/public/2024-01/frank-farian-boney-m-dies-82.jpg?h=216b319c&amp;itok=-GEzUfOu" srcset="/sites/default/files/styles/teaser_card_small/public/2024-01/frank-farian-boney-m-dies-82.jpg?h=216b319c&amp;itok=-GEzUfOu 390w, /sites/default/files/styles/teaser_card_medium/public/2024-01/frank-farian-boney-m-dies-82.jpg?h=216b319c&amp;itok=2NjGVBIo 416w, /sites/default/files/styles/teaser_card/public/2024-01/frank-farian-boney-m-dies-82.jpg?h=216b319c&amp;itok=GQZsIhD0 480w" typeof="foaf:Image" width="480"/>
# </div><div class="teaser-banner teaser-banner-alt">News</div></div><div class="text text-sm xs:text-base leading-[26px] xl:text-xl font-semibold text-white">Boney M founder Frank Farian dies aged 82</div><!--]--></a><!--]--></div><!--[--><img alt="Decorative flame" class="absolute -left-20 top-60 rotate-45 z-0" height="169" src="/_nuxt/flame.cec2aea3.svg" width="131"/><img alt="Decorative flame" class="absolute -right-8 -bottom-24 rotate-45 z-0" height="169" src="/_nuxt/flame.cec2aea3.svg" width="131"/><img alt="Decorative flame" class="absolute origin-top-left -right-24 top-6 -rotate-30 md:right-4 md:top-2 md-rotate-12 z-0" height="169" src="/_nuxt/flame.cec2aea3.svg" width="131"/><!--]--><!-- --></section><!--]--><!--]--><!--]--><!--]--><!-- --><div class="flex flex-col space-y-6 gutter" id="comments"><div class="comment-form prose mb-6" element="drupal-comment-anonymous"><label>Leave a comment</label><p class="border-b-2 pb-6 border-white">Join the conversation by joining the Official Charts community and dropping comment.</p><div class="flex flex-col md:flex-row text-center md:text-left space-y-6 md:space-y-0 md:space-x-6"><div><p class="!mb-3">Already registered?</p><p><a class="btn btn-tertiary w-48" href="/user/login/?returnTo=/charts/singles-chart/20240112/7501/#comments">Log in</a></p></div><div><p class="!mb-3">No account?</p><p><a class="btn btn-tertiary w-48" href="/user/register/?returnTo=/charts/singles-chart/20240112/7501/#comments">Register</a></p></div></div></div><!-- --><!--[--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204423"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><img alt="avatar" class="object-cover w-full h-full" src="https://backstage.officialcharts.com/sites/default/files/styles/medium/public/pictures/2024-01/soyeonqueen_2.jpg?itok=kgUlsGy-"/></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">QueencardGIDLE</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-18 14:46:09">18th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">0</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>G-idle coming to dominate the charts when their new album drops #youwannabeaqueencard</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204402"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><p class="m-auto font-semibold text-2xl">G</p></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">griffinfrank49</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-15 10:43:52">15th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">0</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>hi guys!! it’s griffinfrank49. i would just like to say home much the charts make my week 10 times better and that i think the new Ariana grande song is the best song ever to exist. thank you for reading😁😁😁😁😁😁😁🌼</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><div class="ml-16"><!-- --><!--[--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204424"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><img alt="avatar" class="object-cover w-full h-full" src="https://backstage.officialcharts.com/sites/default/files/styles/medium/public/pictures/2024-01/soyeonqueen_2.jpg?itok=kgUlsGy-"/></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">QueencardGIDLE</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-18 14:47:52">18th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>yes we love ariana! stream yes, and? yes!!!! we stan!!!!! arinatorz!!!!</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--]--></div><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204398"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><img alt="avatar" class="object-cover w-full h-full" src="https://backstage.officialcharts.com/sites/default/files/styles/medium/public/pictures/2023-08/ab67616d0000b2731882add8fd275c04e322027d.jpeg?itok=giHVdq6E"/></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">faiyaz</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-14 18:49:58">14th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">0</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>they actually need to sort the charts out so badly bc why is looking at the bottom end of the top 100 like looking at now thats what i call throwbacks</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204394"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><p class="m-auto font-semibold text-2xl">G</p></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">Giovanni</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-14 17:19:48">14th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">0</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>my top 20 (14.1. 2024.)<br/></p><p>1. (1) SWIMMING PAUL – the way it goes (2nd week at No.1)</p><p>2. (9) THE LIBERTINES – night of the hunter</p><p>3. (3) LIAM BAILEY – dance with me</p><p>4. (2) SOFIA KOURTESIS – si te portas bonito (2weeks at No.1)</p><p>5. (4) PANGEAUX – holdin' on</p><p>6. (8) RAC ft GREAT GOOD FINE OK – fine</p><p>7. (6) FRED AGAIN.. &amp; BABY KEEM – leavemealone </p><p>8. <strong>NEW </strong>– SPRINTS – heavy </p><p>9. (5) THE KILLERS – spirit</p><p>10. <strong>NEW</strong> – TENTENDO x TAJ RALPH – out of sight</p><p><br/></p><p>11. (11) JAX JONES ft ROBBIE G – forever </p><p>12. (14) PAUL RUSSELL – lil boo thang</p><p>13. (12) SHYGIRL – f@k€</p><p>14. (16) SKEPTA ft OSSIE &amp; HARRY STONE – smoke in your eyes</p><p>15. (13) DUCKS LTD. – hollowed out</p><p>16. (20) MATEO SANTIAGO ft BADBADNOTGOOD &amp; CHARLOTTE DAY WILSON – so just rid yourself on him</p><p>17. (10) MEDUZA x FERRECK DAWN x CLEMENTINE DOUGLAS – I got nothing</p><p>18. (17) CHANNEL TRES – walked in the room</p><p>19. (34) THE VACCINES – love to walk away</p><p>20. (7) THE NATIONAL ft PHOEBE BRIDGERS – laugh track (2weeks at No.1)</p><p>................new songs at chart (top 45)..............</p><p>34. NEW – MGMT – nothing to declare </p><p>35. NEW – JAMIE  – it's so good </p><p>36. NEW – FUTURE ISLANDS – say goodbye</p><p>39. NEW – ARIANA GRANDE – yes, and?</p><p>42. NEW – THE SMILE – friend of a friend</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204392"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><p class="m-auto font-semibold text-2xl">K</p></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">karlmacnaughton</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-14 15:38:52">14th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>Rock in the top 40 for two weeks in a row, although Radio 1 decided to skip Kool-Aid. Shame BMTH only ever last a week!</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204388"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><img alt="avatar" class="object-cover w-full h-full" src="https://backstage.officialcharts.com/sites/default/files/styles/medium/public/pictures/2023-12/social_auth_google_108407754730802414761.jpg?itok=Cg27yjTP"/></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">sashabertold</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-14 07:30:59">14th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>How's TheWeekend &amp; Madonna so popular all of a sudden?</p><p>Did not see that one coming.</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204387"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><img alt="avatar" class="object-cover w-full h-full" src="https://backstage.officialcharts.com/sites/default/files/styles/medium/public/pictures/2023-12/58878_10151446186039036_745639392_n.jpg?itok=Dby_hOXi"/></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">sakgra</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-13 20:38:06">13th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">2</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>wow Sophie i d love to see her at no1 <br/></p><p>and new peak for TheWeeknd and madonna that was unexpected<br/></p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204383"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><img alt="avatar" class="object-cover w-full h-full" src="https://backstage.officialcharts.com/sites/default/files/styles/medium/public/pictures/2024-01/beach%20boys_1.jpg?itok=eWf0OmEc"/></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">Sunshine Gal</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-13 14:20:16">13th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>hey what's up everyone!  who's 'shed 7'?  never heard of them...if any of you are fans of theirs, def. recommend some of their tracks to check out.  </p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><div class="ml-16"><!-- --><!--[--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204391"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><p class="m-auto font-semibold text-2xl">K</p></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">karlmacnaughton</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-14 15:34:54">14th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>You could try Getting Better and Chasing Rainbows; those are my favourites anyway.</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--]--></div><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204380"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><p class="m-auto font-semibold text-2xl">M</p></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">maciedeclines</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-13 01:38:29">13th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>hoping I Remember Everything can go top 10 </p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204379"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><p class="m-auto font-semibold text-2xl">M</p></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">maciedeclines</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-13 01:37:30">13th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">2</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>Stick Season is a great song but hoping Murder On The Dancefloor or even yes, and? can eventually overtake it</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204377"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><p class="m-auto font-semibold text-2xl">M</p></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">maciedeclines</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-13 01:31:09">13th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>top 40 re-rank</p><p><br/></p><p>Great:</p><p>1) Murder On The Dancefloor</p><p>2) greedy</p><p>3) vampire</p><p>4) exes</p><p>5) I Remember Everything</p><p>6) Houdini</p><p>7) Perfect (Exceeder)</p><p>8) Cruel Summer</p><p>9) Lovin On Me</p><p>10) Stick Season</p><p>11) Can’t Catch Me Now</p><p>12) Strangers (Kenya Grace)</p><p>13) Prada</p><p>14) Asking</p><p>15) DNA (Loving You)</p><p><br/></p><p>Good:</p><p>16) leavemealone</p><p>17) Agora Hills</p><p>18) Body Moving</p><p>19) On My Love</p><p>20) My Love Mine All Mine</p><p>21) Feather</p><p>22) Lose Control</p><p>23) Everybody</p><p>24) Surround Sound</p><p>25) Pink Friday Girls</p><p>26) Popular</p><p>27) Rich Baby Daddy</p><p>28) Water</p><p>29) Northern Attitude</p><p><br/></p><p>Decent:</p><p>30) Practice</p><p>31) Strangers (Lewis Capaldi)</p><p>32) Unwritten</p><p><br/></p><p>Okay:</p><p>33) Toxic (Freestyle)</p><p><br/></p><p>Mid:</p><p>34) Lil Boo Thang</p><p>35) FTCU</p><p><br/></p><p>Bad:</p><p>N/A</p><p><br/></p><p>Awful:</p><p>36) Just Another Rainbow </p><p><br/></p><p>Haven’t Heard</p><p>37) Kool Aid</p><p>38) Angel Numbers / Ten Toes</p><p>39) One Of The Girls</p><p>40) Runaway</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><div class="ml-16"><!-- --><!--[--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204378"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><p class="m-auto font-semibold text-2xl">M</p></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">maciedeclines</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-13 01:31:36">13th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>this is pretty wrong but hey, it’s 1:30am please forgive me</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--]--></div><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204370"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><img alt="avatar" class="object-cover w-full h-full" src="https://backstage.officialcharts.com/sites/default/files/styles/medium/public/pictures/2024-01/Gracie_Abrams_-_Good_Riddance.png?itok=pi-WzhNh"/></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">itsnoodleszn_</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-12 18:37:43">12th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>i think that stick season song will be lingering for a bit because cd and 7” singles are dropping next week, and this is kinda saying a lot considering this would’ve spent the december at number 1 without the yearly christmas takeover. it’s also kinda nice to see an older drake song back (take care is a great album), feather enter the top 20 and songer in the top 40 at last. i’ve had my eyes on that guy since december 2022. lose control rising kinda  though, and i can’t help but laugh at liam gallagher falling from grace to land 14 places below his expected first look position.</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204369"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><img alt="avatar" class="object-cover w-full h-full" src="https://backstage.officialcharts.com/sites/default/files/styles/medium/public/pictures/2024-01/Gracie_Abrams_-_Good_Riddance.png?itok=pi-WzhNh"/></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">itsnoodleszn_</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-12 18:33:06">12th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">-2</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>it’s been months since lewis capaldi had a charting hit, and nearly seven months since glastonbury, and i swore to never speak about him again following that pretentious album. but the screaming scot we all know (and apparently “love”) is back and after seven months, i can finally give my two cents.</p><p>lewis capaldi’s meltdown at glastonbury was unprofessional, uncalled for, and disrespectful to the fans who were in that pyramid stage crowd wanting to see him and instead they got someone who threw a tantrum and didn’t finish his  set. i hope they never invite him back. that’s my two cents. have a great weekend.</p></div>
# ...
# <div><p>Embarrassing lol</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204358"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><img alt="avatar" class="object-cover w-full h-full" src="https://backstage.officialcharts.com/sites/default/files/styles/medium/public/pictures/2023-07/penguins.PNG?itok=PziN4dlV"/></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">Piran</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-12 17:59:19">12th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">0</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>I can't remember ever seeing a song fall that low after being #1 on a First Look! 😩</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204373"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><img alt="avatar" class="object-cover w-full h-full" src="https://backstage.officialcharts.com/sites/default/files/styles/medium/public/pictures/2024-01/Gracie_Abrams_-_Good_Riddance.png?itok=pi-WzhNh"/></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">itsnoodleszn_</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-12 18:41:17">12th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>insert that clip of drake saying “embarrassing~”</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--]--></div><!--]--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204343"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><img alt="avatar" class="object-cover w-full h-full" src="https://backstage.officialcharts.com/sites/default/files/styles/medium/public/pictures/2024-01/social_auth_google_107991243996603332037.jpg?itok=fyXm0QgE"/></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">hana</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-12 17:45:02">12th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div>new hi</div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><div class="ml-16"><!-- --><!--[--><!--[--><div class="drupal-comment pt-0 pl-0 m-4 mt-2 mb-0 bg-white" id="comment-204407"><div class="flex lg:h-12 bg-brand-cobalt rounded-t-md text-white relative"><div class="w-16 h-16 lg:w-20 lg:h-20 absolute -top-4 -left-4 rounded-full bg-black flex justify-center border-brand-cobalt border-4 overflow-hidden"><p class="m-auto font-semibold text-2xl">G</p></div><div class="flex flex-grow flex-wrap justify-between py-1 pl-16 lg:pl-14"><h4 class="leading-tight lg:ml-8 my-auto font-semibold text-base py-0.5">griffinfrank49</h4><time class="leading-tight lg:ml-8 sm:ml-auto my-auto font-light mr-5 py-0.5" datetime="2024-01-15 10:54:25">15th January 2024</time></div></div><div class="rounded-b-md"><div class="flex"><div class="min-w-fit"><div class="min-w-fit w-16 mt-8 flex justify-center pb-4"><div class="flex flex-col gap-2 items-center"><!-- --><!-- --><div><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><div class="bg-black text-white rounded-md text-xs text-center px-1.5 cursor-help" data-v-5784ed69-s="">-1</div><!--]--></div><div class="popper" data-v-5784ed69="" style="display:none;"><!--[-->Vote score<!--]--><div data-popper-arrow="" data-v-20b7fd4a="" data-v-5784ed69="" id="arrow"></div></div></div></div></div></div></div><div class="flex justify-between flex-col w-full mr-4"><div class="mt-4 prose pr-6">
# <div><p>HEY! nice meeting you!! I'm new too :)</p></div>
# </div><div class="flex space-x-4 text-brand-pink my-3"><!-- --><!-- --><!-- --></div><!-- --></div></div></div></div><!-- --><!--]--><!--]--></div><!--]--><!--]--></div></main><div class="lg:min-w-[320px] lg:w-[320px] lg:mr-6 xl:mr-0 xl:min-w-[400px] xl:w-[400px]" id="sidebar"><aside class="flex flex-col space-y-8 h-full pt-6 md:pt-8"><!--[--><div class="countdown bg-brand-cobalt p-4 lg:p-4 xl:p-6 -mt-8" element="drupal-block-countdown-block"><h4 class="text-brand-fresh font-bold mb-3 text-2xl xl:text-[34px] uppercase font-super text-center">New Top 40 in…</h4><div class="text-center flex text-white space-x-8" data-digits="4"><div class="basis-1/4 relative"><div class="font-bold leading-tighter text-3xl lg:text-2xl xl:text-3xl"> </div><div class="text-sm lg:text-xs xl:text-sm">Days</div><span class="w-0.5 h-3 bg-brand-fresh block absolute -right-4 top-0 bottom-0 my-auto"></span></div><div class="basis-1/4 relative"><div class="font-bold leading-tighter text-3xl lg:text-2xl xl:text-3xl"> </div><div class="text-sm lg:text-xs xl:text-sm">Hours</div><span class="w-0.5 h-3 bg-brand-fresh block absolute -right-4 top-0 bottom-0 my-auto"></span></div><div class="basis-1/4 relative"><div class="font-bold leading-tighter text-3xl lg:text-2xl xl:text-3xl"> </div><div class="text-sm lg:text-xs xl:text-sm">Minutes</div><span class="w-0.5 h-3 bg-brand-fresh block absolute -right-4 top-0 bottom-0 my-auto"></span></div><div class="basis-1/4 relative"><div class="font-bold leading-tighter text-3xl lg:text-2xl xl:text-3xl"> </div><div class="text-sm lg:text-xs xl:text-sm">Seconds</div></div></div></div><div blockid="84" class="" element="drupal-block-content-ignite-advert" type="content_ignite_advert"><div class="relative flex justify-center items-center flex-wrap bg-design-hoverGreige" style=""><div class="" id="ci_ad_300x250_1"></div></div></div><div class="bg-brand-cobalt p-6 lg:p-4 xl:p-6 border-t-8 border-brand-pink" element="drupal-block-archive-access-block"><h3 class="font-bold mb-3 text-2xl uppercase font-super text-white text-center">Access the archive</h3><form action="#" class="flex flex-col flex-grow chart-form"><input aria-label="Chart selection" class="w-full" max="2024-01-26" required="" type="date" value="2024-01-26"/><div class="v-select vs--single vs--searchable" dir="auto"><!--[--><!--]--><div aria-expanded="false" aria-label="Search for option" aria-owns="vs13540__listbox" class="vs__dropdown-toggle" id="vs13540__combobox" role="combobox"><div class="vs__selected-options"><!--[--><!--[--><span class="vs__selected"><!--[-->Official Singles Chart Top 100<!--]--><!-- --></span><!--]--><!--]--><!--[--><input aria-autocomplete="list" aria-controls="vs13540__listbox" aria-labelledby="vs13540__combobox" autocomplete="off" class="vs__search" type="search" value=""/><!--]--></div><div class="vs__actions"><button aria-label="Clear Selected" class="vs__clear" title="Clear Selected" type="button"><svg height="10" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M6.895455 5l2.842897-2.842898c.348864-.348863.348864-.914488 0-1.263636L9.106534.261648c-.348864-.348864-.914489-.348864-1.263636 0L5 3.104545 2.157102.261648c-.348863-.348864-.914488-.348864-1.263636 0L.261648.893466c-.348864.348864-.348864.914489 0 1.263636L3.104545 5 .261648 7.842898c-.348864.348863-.348864.914488 0 1.263636l.631818.631818c.348864.348864.914773.348864 1.263636 0L5 6.895455l2.842898 2.842897c.348863.348864.914772.348864 1.263636 0l.631818-.631818c.348864-.348864.348864-.914489 0-1.263636L6.895455 5z"></path></svg></button><!--[--><svg class="vs__open-indicator" height="10" role="presentation" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M9.211364 7.59931l4.48338-4.867229c.407008-.441854.407008-1.158247 0-1.60046l-.73712-.80023c-.407008-.441854-1.066904-.441854-1.474243 0L7 5.198617 2.51662.33139c-.407008-.441853-1.066904-.441853-1.474243 0l-.737121.80023c-.407008.441854-.407008 1.158248 0 1.600461l4.48338 4.867228L7 10l2.211364-2.40069z"></path ...
# <drupal-media type="image" view-mode="default"><field-image><div> <img alt=" Name Christmas Number 1 news" sizes="100vw" src="/sites/default/files/styles/content_column_mobile/public/2023-11/Christmas%20Number%201%20news.png?itok=pjqWOrcV" srcset="/sites/default/files/styles/content_column_tablet/public/2023-11/Christmas%20Number%201%20news.png?itok=olcCU7nZ 400w" typeof="foaf:Image"/></div>
# </field-image></drupal-media></a>
# <p> </p>
# <p> </p>
# </div><div blockid="61" class="md:sticky top-[calc(var(--header-height)+var(--padd))]" element="drupal-block-content-ignite-advert" type="content_ignite_advert"><div class="relative flex justify-center items-center flex-wrap bg-design-hoverGreige" style=""><div class="" id="ci_ad_300x600_1"></div></div></div><!--]--></aside></div></div></div><footer class="bg-brand-cobalt text-white mt-16"><div class="container gutter flex flex-col pt-8"><nav class="cols gap-0 sm:gap-12"><div class="col sm:col-1/2 lg:col-1/4"><div><ol class="flex flex-col gap-3 mb-14"><!--[--><li><div><h4 class="font-bold mb-3 text-xl md:text-lg uppercase text-brand-fresh">Who we are</h4><ol class="flex flex-col gap-3 mb-14"><!--[--><li><a class="text-white hover:underline" href="/who-we-are/the-official-charts/">The Official Charts</a></li><li><a class="text-white hover:underline" href="/who-we-are/history-official-charts/">History of the Official Charts</a></li><li><a class="text-white hover:underline" href="/who-we-are/our-charts-and-data/">Our charts and data</a></li><li><a class="text-white hover:underline" href="/who-we-are/how-we-built-our-database/">How our database was built</a></li><li><a class="text-white hover:underline" href="/who-we-are/how-to-search-our-database/">How to search our database</a></li><li><a class="text-white hover:underline" href="/who-we-are/contact-us/">Contact Us</a></li><li><a class="text-white hover:underline" href="/who-we-are/copyright-notice/">Copyright notice</a></li><li><a class="text-white hover:underline" href="/who-we-are/privacy-policy/">Privacy Policy</a></li><li><a class="text-white hover:underline" href="/who-we-are/cookie-policy/">Cookie Policy</a></li><!--]--></ol></div></li><!--]--></ol></div></div><div class="col sm:col-1/2 lg:col-1/4"><div><ol class="flex flex-col gap-3 mb-14"><!--[--><li><div><h4 class="font-bold mb-3 text-xl md:text-lg uppercase text-brand-fresh">Getting into the charts</h4><ol class="flex flex-col gap-3 mb-14"><!--[--><li><a class="text-white hover:underline" href="/getting-into-the-charts/how-the-charts-are-compiled/">How the charts are compiled</a></li><li><a class="text-white hover:underline" href="/getting-into-the-charts/releasing-your-music/">Releasing your music</a></li><li><a class="text-white hover:underline" href="/getting-into-the-charts/registering-release/">Registering a release</a></li><li><a class="text-white hover:underline" href="/getting-into-the-charts/meeting-the-chart-rules/">Meeting the chart rules</a></li><li><a class="text-white hover:underline" href="/getting-into-the-charts/the-chart-retailers/">The chart retailers</a></li><!--]--></ol></div></li><!--]--></ol></div></div><div class="col sm:col-1/2 lg:col-1/4"><div><ol class="flex flex-col gap-3 mb-14"><!--[--><li><div><h4 class="font-bold mb-3 text-xl md:text-lg uppercase text-brand-fresh">Our business services</h4><ol class="flex flex-col gap-3 mb-14"><!--[--><li><a class="text-white hover:underline" href="/our-business-services/our-services/">Our services</a></li><li><a class="text-white hover:underline" href="/our-business-services/b2b-data/">B2B data</a></li><li><a class="text-white hover:underline" href="/our-business-services/chart-licensing/">Chart licensing</a></li><li><a class="text-white hover:underline" href="/our-business-services/brand-licensing/">Brand licensing</a></li><li><a class="text-white hover:underline" href="/our-business-services/advertising-on-officialchartscom/">Advertising on OfficialCharts.com</a></li><!--]--></ol></div></li><!--]--></ol></div></div><div class="col sm:col-1/2 lg:col-1/4"><h4 class="font-bold mb-3 text-xl md:text-lg uppercase text-brand-fresh">Follow us</h4><ol class="flex gap-4 items-center pl-2 md:mt-8 mb-12"><!--[--><li><div class="inline-block" data-v-5784ed69="" style="border: 12px solid transparent; margin: -12px;"><div data-v-5784ed69=""><!--[--><a data-v-5784ed69-s="" href="https://www.tiktok.com/@officialukcharts" target="_blank"><img alt="TikTok icon" class="in ...
# </html>

# %% [markdown]
# > - Antes de nada lo que tenemos que mirar es como encontrar las etiquetas dentro de este html que reunen la info que nosotros queremos sacar de esa web.
# > - Para ello necesitamos realizar una exploración visual dentro de la página web
# > - De nuestro objeto soup utilizamos metodos para localizar la información. Método `.find_all()` que lo que hace es aceptar una string que es el tag que nosotros estamos buscando dentro de este html. Puede aceptar como segundo argumento un diccionario en el que indicamos el tipo de tag y la string que estamos buscando.

# %% [markdown]
# ## 3.1 Localizando la información por etiquetas

# %% [markdown]
# > - Definimos las columnas que vamos a necesitar

# %%
columnas = ["position", "artist", "title"]

# %% [markdown]
# ### Localizamos el número que ocupa en la lista

# %%
posicion0_10 = [x.text for x in soup.find_all("span", {"class":"digits1 chart-key font-bold"})]
posicion11_99 = [x.text for x in soup.find_all("span", {"class":"digits2 chart-key font-bold"})]
posicion11_100 = [x.text for x in soup.find_all("span", {"class":"digits3 chart-key font-bold"})]
posicion = posicion0_10 + posicion11_99 + posicion11_100
len(posicion)
# Out:
# 100

# %% [markdown]
# > - Mejoramos el código anterior con un bucle para no repetir código

# %%
position = [x.text.replace("Number", "") for digits in range(1, 4) for x in soup.find_all("span", {"class": f"digits{digits} chart-key font-bold"})]
len(position)
# Out:
# 100

# %% [markdown]
# ### Localizamos al artista

# %% [markdown]
# > - Método `.replace()` para arreglar los nombres
# > - Método `.title()` para que solo la primera sea mayúscula

# %%
artist = [x.text.replace("/", " & ").title() for x in soup.find_all("a", {"class":"chart-artist text-lg inline-block"})]

# %%
len(artist)
# Out:
# 100

# %% [markdown]
# ### Localizamos el título de la canción

# %%
title = [x.text.replace("New", "").title() for x in soup.find_all("a", {"class":"chart-name font-bold inline-block"})]

# %%
len(title)
# Out:
# 100

# %% [markdown]
# ### Creamos el DataFrame a partir de un diccionario

# %%
import pandas as pd
dct = dict ([("position", position), ("artist", artist), ("title", title)])
df = pd.DataFrame(dct)
df = df.set_index("position") # Ponemos como índdice la posición en la lista
df.head(10)
# Out:
#                                   artist                     title
# position
#  1                            Noah Kahan              Stick Season
#  2                   Sophie Ellis-Bextor  Murder On The Dancefloor
#  3                           Jack Harlow               Lovin On Me
#  4         Casso & Raye & D-Block Europe                     Prada
#  5                            Tate Mcrae                    Greedy
#  6                           Teddy Swims              Lose Control
#  7                          Taylor Swift              Cruel Summer
#  8                                  Tyla                     Water
#  9                              Dua Lipa                   Houdini
#  10       Billy Gillies Ft Hannah Boleyn          Dna (Loving You)

# %% [markdown]
# ## 3.2 Table Rows

# %% [markdown]
# > - Puede ser que en otras páginas web no se siga el DOM y no este bien estructurado el código HTML, lo cual puede dificultar mucho la extracción de los datos
# > - Estos table rows contienen toda la información de una "fila" y por ello vamos a iterar sobre ellos
# > - Método muy útil en caso de que la extracción de info por etiquetas se nos pueda complicar
# > - *Justo en esta web no tenemos **table rows (tr)**, cogeremos el div que tiene todo el contenido de cada uno de los elementos e iteraremos sobre él*

# %%
data = [x.text for x in soup.find_all("div", {"class":"chart-item-content relative flex w-full"})]
data[0]
# Out:
# 'Number 1STICK SEASONNOAH KAHANLW: 1, Peak: 1, Weeks: 15'

# %% [markdown]
# > - Con el código que se muestra a continuación, transformamos los números que marcan la posición en integers para poder realizar una separación más adelante

# %%
def clean_rows(lista):

  new_list = []

  for row in lista:
    try:
      int(row[7])
      new_list.append(row)

    except:
      pass

  return new_list

# %%
rows = clean_rows(data)

# %% [markdown]
# > - Función filter para filtar una lista y que nos devuelva solo los elementos que cumplan una condición que nosotros imponemos. `filter(condicion, iterable)`

# %% [markdown]
# # 4.Contruyendo un Web Spider

# %%
import pandas as pd

# %%
dct = {
    "position" : position,
    "artist" : artist,
    "title" : title
}

df = pd.DataFrame(dct)
df = df.set_index("position") # Ponemos como índice la posición en la lista
df["chart"] = "UK" # Incluimos el páis en la que se ha obtenido la lista

# %% [markdown]
# > - Buscamos la fecha para identificar al DataFrame. En este caso la lista se divide por semanas

# %%
import datetime

# %%
semana = datetime.datetime.today().strftime("%V") #Para saber en que semana del año estamos

# %%
df["week"] = int(semana)
df.head()
# Out:
#                                  artist                     title chart  week
# position
#  1                           Noah Kahan              Stick Season    UK     4
#  2                  Sophie Ellis-Bextor  Murder On The Dancefloor    UK     4
#  3                          Jack Harlow               Lovin On Me    UK     4
#  4        Casso & Raye & D-Block Europe                     Prada    UK     4
#  5                           Tate Mcrae                    Greedy    UK     4

# %% [markdown]
# ## 4.1 Construyendo el spider

# %%
def listas_uk(url):
  html = requests.get(url)
  soup = BeautifulSoup(html.content)

  columnas = ["position", "artist", "title"]

  position = [x.text.replace("Number", "") for digits in range(1, 4) for x in soup.find_all("span", {"class": f"digits{digits} chart-key font-bold"})]
  artist = [x.text.replace("/", " & ").title() for x in soup.find_all("a", {"class":"chart-artist text-lg inline-block"})]
  title = [x.text.replace("New", "").title() for x in soup.find_all("a", {"class":"chart-name font-bold inline-block"})]

  dct = {
    "position" : position,
    "artist" : artist,
    "title" : title
    }

  df = pd.DataFrame(dct)
  df = df.set_index("position") # Ponemos como índice la posición en la lista

  df["chart"] = "UK" # Incluimos el páis en la que se ha obtenido la lista

  semana = datetime.datetime.today().strftime("%V")  #Para saber en que semana del año estamos
  df["week"] = int(semana)

  return df

# %%
nuevos_datos = listas_uk(url)

# %%
nuevos_datos
# Out:
#                                  artist                      title chart  week
# position
#  1                           Noah Kahan               Stick Season    UK     4
#  2                  Sophie Ellis-Bextor   Murder On The Dancefloor    UK     4
#  3                          Jack Harlow                Lovin On Me    UK     4
#  4        Casso & Raye & D-Block Europe                      Prada    UK     4
#  5                           Tate Mcrae                     Greedy    UK     4
# ...                                 ...                        ...   ...   ...
#  96                Whethan & Elley Duhe          Money On The Dash    UK     4
#  97                       Goo Goo Dolls                       Iris    UK     4
#  98                      Olivia Rodrigo       Reall-American Bitch    UK     4
#  99       Chris Brown Ft Davido & Lojay                Sensational    UK     4
#  100                         Zach Bryan  Resomething In The Orange    UK     4
#
# [100 rows x 4 columns]

# %%
nuevos_datos["artist"].value_counts()
# Out:
# Noah Kahan                     3
# Olivia Rodrigo                 3
# Lewis Capaldi                  3
# Taylor Swift                   3
# Dua Lipa                       2
#                               ..
# Eliza Rose & Calvin Harris     1
# Nicki Minaj Ft Lil Uzi Vert    1
# Kanye West Ft Pusha T          1
# Paul Russell                   1
# Zach Bryan                     1
# Name: artist, Length: 86, dtype: int64

# %% [markdown]
# ## 4.2 Acceso a URLS para obtener listas de otras fechas

# %%
url = "https://www.officialcharts.com/charts/singles-chart/20240112/7501/"

fecha = "20240112"

# %%
fecha
# Out:
# '20240112'

# %% [markdown]
# > - Parseamos/transformamos el objeto con la fecha que es de tipo string a formato **dateTime**

# %%
fecha_obj = datetime.datetime.strptime(fecha, "%Y%m%d")

fecha_obj
# Out:
# datetime.datetime(2024, 1, 12, 0, 0)

# %% [markdown]
# > - `datetime.timedelta` para realizar variaciones en las fechas

# %%
fecha_nueva = fecha_obj - datetime.timedelta(days=7)

# %% [markdown]
# > - Lo volvemos a transformar a formato string para poder modificar la URL de forma iterativa

# %%
fecha_nueva.strftime("%Y%m%d")
# Out:
# '20240105'

# %%
def restar_semanas(fecha_string, n_semanas_restar):

  fecha_obj = datetime.datetime.strptime(fecha_string, "%Y%m%d")

  fecha_nueva = fecha_obj - datetime.timedelta(weeks=n_semanas_restar)

  return fecha_nueva.strftime("%Y%m%d")

# %%
fecha
# Out:
# '20240112'

# %%
restar_semanas(fecha, n_semanas_restar = 2)
# Out:
# '20231229'

# %% [markdown]
# ### 4.2.1 Cambiar URL

# %%
url_nueva= "https://www.officialcharts.com/charts/singles-chart/" + fecha + "/7501/"

# %% [markdown]
# ## 4.3 Web Spider múltiple

# %%
fecha_actual =  "20240112"

def spider_listas(fecha_actual, n_semanas_restar):

  df_list = []

  for i in range(n_semanas_restar):

    nueva_fecha = restar_semanas(fecha_actual, i)

    url_nueva= "https://www.officialcharts.com/charts/singles-chart/" + nueva_fecha + "/7501/"

    df = listas_uk(url_nueva)

    semana = datetime.datetime.strptime(nueva_fecha, "%Y%m%d").strftime("%V")

    df["week"] = semana

    df_list.append(df)

  return pd.concat(df_list)

# %%
df = spider_listas(fecha, 5)

# %%
df
# Out:
#                                  artist                     title chart week
# position
#  1                           Noah Kahan              Stick Season    UK   02
#  2                  Sophie Ellis-Bextor  Murder On The Dancefloor    UK   02
#  3                          Jack Harlow               Lovin On Me    UK   02
#  4        Casso & Raye & D-Block Europe                     Prada    UK   02
#  5                           Tate Mcrae                    Greedy    UK   02
# ...                                 ...                       ...   ...  ...
#  96         Becky Hill & Chase & Status                Disconnect    UK   50
#  97                           Jung Kook      Standing Next To You    UK   50
#  98                  Fred Again & Jozzy                     Reten    UK   50
#  99                            Pinkfong                Baby Shark    UK   50
#  100      Richy Mitch & The Coal Miners               Reevergreen    UK   50
#
# [500 rows x 4 columns]

# %%
df["artist"].value_counts()
# Out:
# Taylor Swift           15
# Tate Mcrae             13
# Noah Kahan             12
# Olivia Rodrigo         11
# Nicki Minaj             7
#                        ..
# Tears For Fears         1
# Drake                   1
# Nathan Evans            1
# Natasha Bedingfield     1
# Drake Ft Yeat           1
# Name: artist, Length: 168, dtype: int64
